# %%
import pandas as pd

# %%
stats = pd.read_csv("players_teams_mvps_stats_final.csv")

# %%
del stats["Unnamed: 0"]

# %%
stats
# Out:
#                    Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0              A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...
# 1             Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...
# 2          Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...
# 3           Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...
# 4            James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...
# ...                   ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 14692   Jordan McLaughlin  PG   23  MIN  30   2  19.7  2.9   5.9  0.489  ...
# 14693         Josh Okogie  SG   21  MIN  62  28  25.0  2.7   6.4  0.427  ...
# 14694  Karl-Anthony Towns   C   24  MIN  35  35  33.9  9.0  17.8  0.508  ...
# 14695        Kelan Martin  SF   24  MIN  31   4  16.0  2.3   5.8  0.392  ...
# 14696            Naz Reid   C   20  MIN  30  11  16.5  3.3   8.1  0.412  ...
#
# ...

# %%
pd.isnull(stats).sum()
# Out:
# Player       0
# Pos          0
# Age          0
# Tm           0
# G            0
# GS           0
# MP           0
# FG           0
# FGA          0
# FG%         59
# 3P           0
# 3PA          0
# 3P%          0
# 2P           0
# 2PA          0
# 2P%        100
# eFG%        59
# FT           0
# FTA          0
# FT%        521
# ORB          0
# DRB          0
# TRB          0
# AST          0
# STL          0
# BLK          0
# TOV          0
# PF           0
# PTS          0
# Year         0
# Pts Won      0
# Pts Max      0
# Share        0
# Team         0
# W            0
# L            0
# W/L%         0
# GB           0
# PS/G         0
# PA/G         0
# SRS          0
# dtype: int64

# %%
stats[pd.isnull(stats["FT%"])][["Player", "FTA"]]
# Out:
#                 Player  FTA
# 74          John Coker  0.0
# 109       Jason Sasser  0.0
# 121          Matt Fish  0.0
# 145    Adrian Caldwell  0.0
# 159       Bruno Šundov  0.0
# ...                ...  ...
# 14456    Mark McNamara  0.0
# 14488      Luke Zeller  0.0
# 14570      Myron Brown  0.0
# 14598      Malcolm Lee  0.0
# 14676      Steve Novak  0.0
#
# [521 rows x 2 columns]

# %%
stats = stats.fillna(0)

# %%
pd.isnull(stats).sum()
# Out:
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        0
# 3P         0
# 3PA        0
# 3P%        0
# 2P         0
# 2PA        0
# 2P%        0
# eFG%       0
# FT         0
# FTA        0
# FT%        0
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# Year       0
# Pts Won    0
# Pts Max    0
# Share      0
# Team       0
# W          0
# L          0
# W/L%       0
# GB         0
# PS/G       0
# PA/G       0
# SRS        0
# dtype: int64

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
predictors = [ 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year', 'W', 'L', 'W/L%', 'GB', 'PS/G',
       'PA/G', 'SRS']

# %%
train = stats[stats["Year"] < 2022]

# %%
test = stats[stats["Year"] == 2022]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
from sklearn.linear_model import Ridge # Ridge prevents overfitting

reg = Ridge(alpha=0.1) # alpha controls how much coefficient is gonna be shrunk to prevent overfitting

# %%
reg.fit(train[predictors], train["Share"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])
predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)

# %%
predictions
# Out:
#         predictions
# 982    1.391118e-02
# 983   -2.654197e-02
# 984   -4.890397e-03
# 985    1.755707e-02
# 986   -3.272239e-03
# 987    4.182532e-03
# 988    3.292058e-03
# 989    1.270422e-03
# 990    1.052051e-02
# 991   -2.281507e-02
# 992    6.583117e-03
# 993    1.891832e-01
# 994   -2.139281e-02
# 995    9.334188e-04
# 996   -1.551783e-02
# 997    7.960857e-03
# 998   -1.357841e-02
# 1182   4.261384e-03
# 1183  -2.764548e-03
# 1184  -1.265828e-02
# 1185  -2.238334e-03
# 1186  -1.196773e-02
# 1187  -2.404990e-03
# 1188  -2.662748e-02
# 1189   1.907956e-01
# 1190  -1.955606e-02
# 1191  -1.215304e-03
# 1192   3.996799e-03
# 1193  -9.782108e-03
# 1194   2.848498e-02
# 1195   2.124297e-02
# 1247  -9.411834e-04
# 1248  -1.938912e-02
# 1249   2.747041e-02
# 1250  -7.489344e-03
# 1251  -6.995971e-03
# 1252  -1.620616e-02
# 1253   5.081631e-02
# 1254   7.400599e-03
# 1255  -7.563493e-03
# 1256  -3.340360e-03
# 1257  -2.450369e-03
# 1258   4.764694e-02
# 1259  -6.974656e-03
# ...

# %%
combination = pd.concat([test[["Player", "Share"]], predictions], axis = 1)

# %%
combination.sort_values("Share", ascending = False).head(10)
# Out:
#                       Player  Share  predictions
# 993             Nikola Jokić  0.875     0.189183
# 1189             Joel Embiid  0.706     0.190796
# 11616  Giannis Antetokounmpo  0.595     0.219438
# 2068            Devin Booker  0.216     0.091994
# 11423            Luka Dončić  0.146     0.156885
# 1631            Jayson Tatum  0.043     0.094442
# 12091              Ja Morant  0.010     0.120786
# 6565           Stephen Curry  0.004     0.092409
# 2066              Chris Paul  0.002     0.079379
# 11161           Kevin Durant  0.001     0.141073

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(combination["Share"], combination["predictions"])
# Out:
# 0.0022332252419492177

# %%
combination["Share"].value_counts()
# Out:
# 0.000    593
# 0.001      3
# 0.875      1
# 0.706      1
# 0.043      1
# 0.002      1
# 0.216      1
# 0.004      1
# 0.146      1
# 0.595      1
# 0.010      1
# Name: Share, dtype: int64

# %%
combination = combination.sort_values("Share", ascending = False)
combination["Rk"] = list(range(1, combination.shape[0]+1))

# %%
combination = combination.sort_values("predictions", ascending = False)
combination["Predictions_Rk"] = list(range(1, combination.shape[0]+1))

# %%
combination.sort_values("predictions", ascending = False).head(30)
# Out:
#                         Player  Share  predictions   Rk  Predictions_Rk
# 11616    Giannis Antetokounmpo  0.595     0.219438    3               1
# 1189               Joel Embiid  0.706     0.190796    2               2
# 993               Nikola Jokić  0.875     0.189183    1               3
# 8394              LeBron James  0.001     0.157946   11               4
# 11423              Luka Dončić  0.146     0.156885    5               5
# 11161             Kevin Durant  0.001     0.141073   10               6
# 12091                Ja Morant  0.010     0.120786    7               7
# 11747               Trae Young  0.000     0.109073  269               8
# 8385             Anthony Davis  0.000     0.108408  141               9
# 1294              James Harden  0.000     0.100986  380              10
# 4514             DeMar DeRozan  0.001     0.100805   12              11
# 11794              Rudy Gobert  0.000     0.097356  302              12
# ...

# %%
def find_ap(combination):
    actual = combination.sort_values("Share", ascending = False).head(5)
    predicted = combination.sort_values("predictions", ascending = False)

    ps = []
    found = 0
    seen = 1

    for index, row in combination.iterrows():
        if row["Player"] in actual["Player"].values:
            found += 1
            ps.append(found/seen)
        seen += 1
    return sum(ps) / len(ps)

# %%
ap = find_ap(combination)

# %%
ap
# Out:
# 0.8225
